# %% [markdown]
# # Hello World!
# **Let's Go!**

# %%
2*(3+4)
# Out:
# 14

# %% [markdown]
# *Display something*
#
#
# ```
# First value: 1
# ```

# %%
'''
Print a value
'''

print('First value: ',1)
# Out:
# First value:  1

# %% [markdown]
# **Calling a function `sort`**
#
# 1. Make a list of
#
# ```
# Number = [4,3,2,1]
# ```
#
# 2. Use the function `sort()` to sort the Numbers.
#
# 3. Display by using `print`.

# %%
Number = [4,3,2,1]
Number.sort()
print(Number)
# Out:
# [1, 2, 3, 4]
